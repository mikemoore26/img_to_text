# %%
#pip install opencv-python

# %%
#pip install pytesseract

# %%
#!pip install tesseract
# !pip install tesseract-ocr
# Out:
# Collecting tesseract-ocr
#   Using cached tesseract-ocr-0.0.1.tar.gz (33 kB)
# Requirement already satisfied: cython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tesseract-ocr) (0.29.24)
# Building wheels for collected packages: tesseract-ocr
#   Building wheel for tesseract-ocr (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"'; __file__='"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-wheel-sng8z5k5
#        cwd: /private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/
#   Complete output (122 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   file tesseract_ocr.py (for module tesseract_ocr) not found
#   file tesseract_ocr.py (for module tesseract_ocr) not found
#   running build_ext
#   building 'tesseract_ocr' extension
#   creating build
#   creating build/temp.macosx-10.9-x86_64-3.9
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c tesseract_ocr.cpp -o build/temp.macosx-10.9-x86_64-3.9/tesseract_ocr.o
#   In file included from tesseract_ocr.cpp:658:
#   In file included from /usr/local/include/tesseract/baseapi.h:26:
#   In file included from /usr/local/include/tesseract/apitypes.h:23:
#   /usr/local/include/tesseract/publictypes.h:33:1: error: unknown type name 'constexpr'
#   constexpr int kPointsPerInch = 72;
#   ^
#   /usr/local/include/tesseract/publictypes.h:38:1: error: unknown type name 'constexpr'
#   constexpr int kMinCredibleResolution = 70;
#   ^
#   /usr/local/include/tesseract/publictypes.h:40:1: error: unknown type name 'constexpr'
#   constexpr int kMaxCredibleResolution = 2400;
#   ^
#   /usr/local/include/tesseract/publictypes.h:45:1: error: unknown type name 'constexpr'
#   constexpr int kResolutionEstimationFactor = 10;
#   ^
#   In file included from tesseract_ocr.cpp:658:
#   In file included from /usr/local/include/tesseract/baseapi.h:30:
#   In file included from /usr/local/include/tesseract/resultiterator.h:27:
#   In file included from /usr/local/include/tesseract/ltrresultiterator.h:27:
#   /usr/local/include/tesseract/unichar.h:34:20: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#   using UNICHAR_ID = int;
#                      ^
#   /usr/local/include/tesseract/unichar.h:51:16: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#   using char32 = signed int;
#                  ^
#   /usr/local/include/tesseract/unichar.h:108:16: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#       using CI = const_iterator;
#                  ^
#   /usr/local/include/tesseract/unichar.h:171:8: error: function definition does not declare parameters
#     char chars[UNICHAR_LEN]{};
#          ^
#   /usr/local/include/tesseract/unichar.h:60:12: error: use of undeclared identifier 'chars'
#       memset(chars, 0, UNICHAR_LEN);
#              ^
#   /usr/local/include/tesseract/unichar.h:78:15: error: use of undeclared identifier 'chars'
#       int len = chars[UNICHAR_LEN - 1];
#                 ^
#   /usr/local/include/tesseract/unichar.h:84:12: error: use of undeclared identifier 'chars'
#       return chars;
#              ^
#   In file included from tesseract_ocr.cpp:658:
#   In file included from /usr/local/include/tesseract/baseapi.h:30:
#   In file included from /usr/local/include/tesseract/resultiterator.h:27:
#   /usr/local/include/tesseract/ltrresultiterator.h:68:24: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#     ~LTRResultIterator() override;
#                          ^
#   In file included from tesseract_ocr.cpp:658:
#   In file included from /usr/local/include/tesseract/baseapi.h:30:
#   /usr/local/include/tesseract/resultiterator.h:49:21: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#     ~ResultIterator() override = default;
#                       ^
#   /usr/local/include/tesseract/resultiterator.h:49:32: warning: defaulted function definitions are a C++11 extension [-Wc++11-extensions]
#     ~ResultIterator() override = default;
#                                  ^
#   /usr/local/include/tesseract/resultiterator.h:56:16: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#     void Begin() override;
#                  ^
#   /usr/local/include/tesseract/resultiterator.h:70:38: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#     bool Next(PageIteratorLevel level) override;
#                                        ^
#   /usr/local/include/tesseract/resultiterator.h:78:55: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#     bool IsAtBeginningOf(PageIteratorLevel level) const override;
#                                                         ^
#   /usr/local/include/tesseract/resultiterator.h:86:66: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#                                   PageIteratorLevel element) const override;
#                                                                    ^
#   /usr/local/include/tesseract/resultiterator.h:103:63: error: a space is required between consecutive right angle brackets (use '> >')
#     virtual std::vector<std::vector<std::pair<const char*, float>>>*
#                                                                 ^~
#                                                                 > >
#   In file included from tesseract_ocr.cpp:658:
#   In file included from /usr/local/include/tesseract/baseapi.h:31:
#   /usr/local/include/tesseract/serialis.h:43:1: error: unknown type name 'constexpr'
#   constexpr size_t countof(T const (&)[N]) noexcept {
#   ^
#   /usr/local/include/tesseract/serialis.h:43:11: warning: variable templates are a C++14 extension [-Wc++14-extensions]
#   constexpr size_t countof(T const (&)[N]) noexcept {
#             ^
#   /usr/local/include/tesseract/serialis.h:43:17: error: expected ';' at end of declaration
#   constexpr size_t countof(T const (&)[N]) noexcept {
#                   ^
#                   ;
#   /usr/local/include/tesseract/serialis.h:43:26: error: unknown type name 'T'
#   constexpr size_t countof(T const (&)[N]) noexcept {
#                            ^
#   /usr/local/include/tesseract/serialis.h:43:38: error: use of undeclared identifier 'N'
#   constexpr size_t countof(T const (&)[N]) noexcept {
#                                        ^
#   /usr/local/include/tesseract/serialis.h:43:42: error: expected function body after function declarator
#   constexpr size_t countof(T const (&)[N]) noexcept {
#                                            ^
#   /usr/local/include/tesseract/serialis.h:52:20: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#   using FileWriter = bool (*)(const GenericVector<char>&, const STRING&);
#                      ^
#   /usr/local/include/tesseract/serialis.h:55:40: error: unknown type name 'size_t'
#   bool DeSerialize(FILE* fp, char* data, size_t n = 1);
#                                          ^
#   /usr/local/include/tesseract/serialis.h:56:41: error: unknown type name 'size_t'
#   bool DeSerialize(FILE* fp, float* data, size_t n = 1);
#                                           ^
#   /usr/local/include/tesseract/serialis.h:57:42: error: unknown type name 'size_t'
#   bool DeSerialize(FILE* fp, int8_t* data, size_t n = 1);
#                                            ^
#   /usr/local/include/tesseract/serialis.h:58:43: error: unknown type name 'size_t'
#   bool DeSerialize(FILE* fp, int16_t* data, size_t n = 1);
#                                             ^
#   /usr/local/include/tesseract/serialis.h:59:43: error: unknown type name 'size_t'
#   bool DeSerialize(FILE* fp, int32_t* data, size_t n = 1);
#                                             ^
#   fatal error: too many errors emitted, stopping now [-ferror-limit=]
#   12 warnings and 20 errors generated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for tesseract-ocr
#   Running setup.py clean for tesseract-ocr
# Failed to build tesseract-ocr
# Installing collected packages: tesseract-ocr
#     Running setup.py install for tesseract-ocr ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"'; __file__='"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-record-n5_08w5u/install-record.txt --single-version-externally-managed --compile --install-headers /Library/Frameworks/Python.framework/Versions/3.9/include/python3.9/tesseract-ocr
#          cwd: /private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/
#     Complete output (122 lines):
#     running install
#     running build
#     running build_py
#     file tesseract_ocr.py (for module tesseract_ocr) not found
#     file tesseract_ocr.py (for module tesseract_ocr) not found
#     running build_ext
#     building 'tesseract_ocr' extension
#     creating build
#     creating build/temp.macosx-10.9-x86_64-3.9
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c tesseract_ocr.cpp -o build/temp.macosx-10.9-x86_64-3.9/tesseract_ocr.o
#     In file included from tesseract_ocr.cpp:658:
#     In file included from /usr/local/include/tesseract/baseapi.h:26:
#     In file included from /usr/local/include/tesseract/apitypes.h:23:
#     /usr/local/include/tesseract/publictypes.h:33:1: error: unknown type name 'constexpr'
#     constexpr int kPointsPerInch = 72;
#     ^
#     /usr/local/include/tesseract/publictypes.h:38:1: error: unknown type name 'constexpr'
#     constexpr int kMinCredibleResolution = 70;
#     ^
#     /usr/local/include/tesseract/publictypes.h:40:1: error: unknown type name 'constexpr'
#     constexpr int kMaxCredibleResolution = 2400;
#     ^
#     /usr/local/include/tesseract/publictypes.h:45:1: error: unknown type name 'constexpr'
#     constexpr int kResolutionEstimationFactor = 10;
#     ^
#     In file included from tesseract_ocr.cpp:658:
#     In file included from /usr/local/include/tesseract/baseapi.h:30:
#     In file included from /usr/local/include/tesseract/resultiterator.h:27:
#     In file included from /usr/local/include/tesseract/ltrresultiterator.h:27:
#     /usr/local/include/tesseract/unichar.h:34:20: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#     using UNICHAR_ID = int;
#                        ^
#     /usr/local/include/tesseract/unichar.h:51:16: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#     using char32 = signed int;
#                    ^
#     /usr/local/include/tesseract/unichar.h:108:16: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#         using CI = const_iterator;
#                    ^
#     /usr/local/include/tesseract/unichar.h:171:8: error: function definition does not declare parameters
#       char chars[UNICHAR_LEN]{};
#            ^
#     /usr/local/include/tesseract/unichar.h:60:12: error: use of undeclared identifier 'chars'
#         memset(chars, 0, UNICHAR_LEN);
#                ^
#     /usr/local/include/tesseract/unichar.h:78:15: error: use of undeclared identifier 'chars'
#         int len = chars[UNICHAR_LEN - 1];
#                   ^
#     /usr/local/include/tesseract/unichar.h:84:12: error: use of undeclared identifier 'chars'
#         return chars;
#                ^
#     In file included from tesseract_ocr.cpp:658:
#     In file included from /usr/local/include/tesseract/baseapi.h:30:
#     In file included from /usr/local/include/tesseract/resultiterator.h:27:
#     /usr/local/include/tesseract/ltrresultiterator.h:68:24: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#       ~LTRResultIterator() override;
#                            ^
#     In file included from tesseract_ocr.cpp:658:
#     In file included from /usr/local/include/tesseract/baseapi.h:30:
#     /usr/local/include/tesseract/resultiterator.h:49:21: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#       ~ResultIterator() override = default;
#                         ^
#     /usr/local/include/tesseract/resultiterator.h:49:32: warning: defaulted function definitions are a C++11 extension [-Wc++11-extensions]
#       ~ResultIterator() override = default;
#                                    ^
#     /usr/local/include/tesseract/resultiterator.h:56:16: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#       void Begin() override;
#                    ^
#     /usr/local/include/tesseract/resultiterator.h:70:38: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#       bool Next(PageIteratorLevel level) override;
#                                          ^
#     /usr/local/include/tesseract/resultiterator.h:78:55: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#       bool IsAtBeginningOf(PageIteratorLevel level) const override;
#                                                           ^
#     /usr/local/include/tesseract/resultiterator.h:86:66: warning: 'override' keyword is a C++11 extension [-Wc++11-extensions]
#                                     PageIteratorLevel element) const override;
#                                                                      ^
#     /usr/local/include/tesseract/resultiterator.h:103:63: error: a space is required between consecutive right angle brackets (use '> >')
#       virtual std::vector<std::vector<std::pair<const char*, float>>>*
#                                                                   ^~
#                                                                   > >
#     In file included from tesseract_ocr.cpp:658:
#     In file included from /usr/local/include/tesseract/baseapi.h:31:
#     /usr/local/include/tesseract/serialis.h:43:1: error: unknown type name 'constexpr'
#     constexpr size_t countof(T const (&)[N]) noexcept {
#     ^
#     /usr/local/include/tesseract/serialis.h:43:11: warning: variable templates are a C++14 extension [-Wc++14-extensions]
#     constexpr size_t countof(T const (&)[N]) noexcept {
#               ^
#     /usr/local/include/tesseract/serialis.h:43:17: error: expected ';' at end of declaration
#     constexpr size_t countof(T const (&)[N]) noexcept {
#                     ^
#                     ;
#     /usr/local/include/tesseract/serialis.h:43:26: error: unknown type name 'T'
#     constexpr size_t countof(T const (&)[N]) noexcept {
#                              ^
#     /usr/local/include/tesseract/serialis.h:43:38: error: use of undeclared identifier 'N'
#     constexpr size_t countof(T const (&)[N]) noexcept {
#                                          ^
#     /usr/local/include/tesseract/serialis.h:43:42: error: expected function body after function declarator
#     constexpr size_t countof(T const (&)[N]) noexcept {
#                                              ^
#     /usr/local/include/tesseract/serialis.h:52:20: warning: alias declarations are a C++11 extension [-Wc++11-extensions]
#     using FileWriter = bool (*)(const GenericVector<char>&, const STRING&);
#                        ^
#     /usr/local/include/tesseract/serialis.h:55:40: error: unknown type name 'size_t'
#     bool DeSerialize(FILE* fp, char* data, size_t n = 1);
#                                            ^
#     /usr/local/include/tesseract/serialis.h:56:41: error: unknown type name 'size_t'
#     bool DeSerialize(FILE* fp, float* data, size_t n = 1);
#                                             ^
#     /usr/local/include/tesseract/serialis.h:57:42: error: unknown type name 'size_t'
#     bool DeSerialize(FILE* fp, int8_t* data, size_t n = 1);
#                                              ^
#     /usr/local/include/tesseract/serialis.h:58:43: error: unknown type name 'size_t'
#     bool DeSerialize(FILE* fp, int16_t* data, size_t n = 1);
#                                               ^
#     /usr/local/include/tesseract/serialis.h:59:43: error: unknown type name 'size_t'
#     bool DeSerialize(FILE* fp, int32_t* data, size_t n = 1);
#                                               ^
#     fatal error: too many errors emitted, stopping now [-ferror-limit=]
#     12 warnings and 20 errors generated.
#     error: command '/usr/bin/gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"'; __file__='"'"'/private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-install-phpidanb/tesseract-ocr_5a7a6bb971a849c0b14deffb78dadfe3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/dk/37sbt0k53451bd1_l_nzws1h0000gn/T/pip-record-n5_08w5u/install-record.txt --single-version-externally-managed --compile --install-headers /Library/Frameworks/Python.framework/Versions/3.9/include/python3.9/tesseract-ocr Check the logs for full command output.
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip install imagemagick
# Out:
# ERROR: Could not find a version that satisfies the requirement imagemagick (from versions: none)
# ERROR: No matching distribution found for imagemagick
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pytesseract
import cv2
import os

# %%
#!brew install tesseract
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/testimage1.jpeg
# ./data/test5.jpg
# ./data/test4.png
# ./data/test1.png
# ./data/test3.png
# ./data/test2.png
# ./data/testimage5.jpeg
# ./data/testimage4.jpeg
# ./data/testimage3.jpeg
# ./data/testimage1.tif
# ./data/testimage2.jpeg

# %%
pytesseract.pytesseract.tesseract_cmd=r'/usr/local/bin/tesseract'

# %%
#pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\\tesseract.exe'

import pytesseract as pyt
import cv2

def ocr_core(img):
    text = pyt.image_to_string(img)
    return text

def get_grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def remove_noise(img):
    return cv2.medianBlur(img,5)

def threshold(img):
    return cv2.threshold(img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
from PIL import Image

# %%
i=5
mine = f"./data/test{i}.png"
tech = f"./data/testimage{i}.jpeg"
img=cv2.imread('./data/testimage1.jpeg')
im = Image.fromarray(mine)
im
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5db02ab96baa> in <module>
#       3 tech = f"./data/testimage{i}.jpeg"
#       4 img=cv2.imread('./data/testimage1.jpeg')
# ----> 5 im = Image.fromarray(mine)
#       6 im
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2752     .. versionadded:: 1.1.6
#    2753     """
# -> 2754     arr = obj.__array_interface__
#    2755     shape = arr["shape"]
#    2756     ndim = len(shape)
#
# AttributeError: 'str' object has no attribute '__array_interface__'

# %%
img = get_grayscale(img)
im = Image.fromarray(img)
im

# convert ./data/testimage1.jpeg -resize 400% -type Grayscale ./data/testimage1.tif
# Out:
# <PIL.Image.Image image mode=L size=1280x381 at 0x7F927E2D92B0>

# %%
im.save("./data/testimage1.tif")

# %%
img = threshold(img)
im = Image.fromarray(img)
im
# Out:
# <PIL.Image.Image image mode=L size=1280x381 at 0x7F927E7A2FA0>

# %%
img = remove_noise(img)
im = Image.fromarray(img)
im
# Out:
# <PIL.Image.Image image mode=L size=1280x381 at 0x7F927E2D9550>

# %%
ocr_core(img)
# Out:
# ' \n\n \n\n   \n\nBenne\n\nns\n\n  \n\n \n\n   \n\n \n\na > g2n¢6\n\n \n\x0c'

# %%
i=5
mine = f"./data/test{i}.jpg"
tech = f"./data/testimage{i}.jpeg"
img=cv2.imread(mine)
im = Image.fromarray(img)
img = get_grayscale(img)
img = threshold(img)
img = remove_noise(img)
ocr_core(img)
# Out:
# ' \n\x0c'

# %%
cv2.imshow('sample image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1
