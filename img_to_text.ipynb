# %%
#pip install opencv-python

# %%
#pip install pytesseract

# %%
#!pip install tesseract
#!pip install tesseract-ocr

# %%
#!pip install imagemagick

# %%
import pytesseract
import cv2
import os

# %%
#!brew install tesseract
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/testimage1.jpeg
# ./data/testimage3 jpeg
# ./data/test5.jpg
# ./data/test4.png
# ./data/test1.png
# ./data/test3.png
# ./data/testimage5 jpeg
# ./data/test2.png
# ./data/testimage4.jpeg
# ./data/testimage1.tif
# ./data/testimage2.jpeg

# %%
pytesseract.pytesseract.tesseract_cmd=r'/usr/local/bin/tesseract'

# %%
#pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\\tesseract.exe'

import pytesseract as pyt
import cv2

def ocr_core(img):
    text = pyt.image_to_string(img)
    return text

def get_grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def remove_noise(img):
    return cv2.medianBlur(img,5)

def threshold(img):
    return cv2.threshold(img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
from PIL import Image

# %%
i=3
mine = f"./data/test{i}.png"
tech = f"./data/testimage{i}.jpeg"
img=cv2.imread(mine)
im = Image.fromarray(img)
im
# Out:
# <PIL.Image.Image image mode=RGB size=686x606 at 0x7FD8BE7C5190>

# %%
img = get_grayscale(img)
im = Image.fromarray(img)
im

# convert ./data/testimage1.jpeg -resize 400% -type Grayscale ./data/testimage1.tif
# Out:
# <PIL.Image.Image image mode=L size=686x606 at 0x7FD8BFF6E4C0>

# %%
im.save("./data/testimage1.tif")

# %%
img = threshold(img)
im = Image.fromarray(img)
im
# Out:
# <PIL.Image.Image image mode=L size=686x606 at 0x7FD8BFF6E280>

# %%
ocr_core(img)
# Out:
# "Am 4, Mai 1771\n\nWie froh bin ich. dal ich weg bin! Bester Freund, was ist das Herz des Menschen! Dich zu verlassen. den ich\nso fiebe. von dem ich unzertrennlich war, und frok zu sein! Ich wei, du verzeihst mir's. Waren nicht meing\nUbrigen Verbindungen recht ausgesucht vom Schicksal, um ein Herz wie das meine 2u angstigen’ Die arme\nLeonor! Und doch war ich unschuldig. Konnt’ ich daftr. daB. wihrend die eigensinniven Reie iter\nSchwester mir cine angenchme Linterhaitung verschafften. daB vine f-eidenschaft in det armen Herzen sich\nbildete? Und doch - bin ich ganz unschuldig? Hab’ ich nicht ihre Empfindungen yenithr” Liab ich mich ich,\nan den ganz wahren Ausdriicken der Natur. die uns so aft zu lachen machten, so wenig Kicherliei sie sare\nselbst ergetzt? Hab’ ich nicht - 0 was ist der Mensch, da ec (ber sich klagen darf? Ich will. lieher Frenad, ich\nverspreche dirs, ich will mich bessern, will nicht mehr ein biGchen Ubel, das uns das Schicksal serlest\nwiederkéuen. wie ich's immer getan habe: ich will das Gegenw drtige seniclicn. und das Vergingene oll tic\nvergangen sein. Gewif. du hast recht. Bester, der Schmerzen waren minder unter den Mensehen, wet six\nnicht - Gott wei8, warum sic so gemacht sind! - mit so viel Emsigheit der Einbildungsbrati sch\nbeschaftigien. die Erinnerungen des vergangenen Cibels auriicheurufen eher aly cine gleiciiyilt\nGegenwart mi ertragen.\n\n \n\n \n\n \n\n \n\n  \n\n     \n\n \n\n \n\nDu bist so gut, meiner Mutter 24 sagen, daB ich ihr Gieschal bestens hetreiben wd ihe ehsteny Nachricht\ndavon geben werde. Ich habe meine Tante gesprochen und bei weitem das ise Weib nicht gefunden, das\nman bei uns aus ihr macht. Sie ist eine muntere, heftige Frau son dem besten Herzen. belt erk kine ihe meiner\nMutter Beschwerden Uber den zuriichgehaltenen Erbschaftsanteil, sie sagte mir ihre Cintinde. U rsacheo wad\ndie Bedingungen, unter welchen sie bereit ware. alles herauscugeben, ual mehr ails wir verlangten RUZ. igh\nmag jetzt nichts davon schreiben, sage meiner Mutter. es wenle alles gut gehen. Und wt habe. mein Leber\nwieder bei diesem kleinen Geschatt gefunden, daG MiBverstindnisse und Ecagheit vtelleieht melt lenagen\nin der Welt machen als List und Bosheit, Wenigstens sind die beaten letteren gow ul seltenet\n\n \n\nObrigens hefinde ich mich hier gar wohl. Die Finsambeit ist meinem Her cen hostbehe: Balsain in dieser\nparadiesischen Gegend, und diese Jabreszeit der Jugend warm unit aller Fife mean «tt ss hausderitles Hers\nJeder Baum, jede Hecke ist ein Straud von [3liten, und man mochle cum Mateokster werden un in dem\nMeer von Wohigeriichen herumschweben und alle seine Nahrung dann finden 2u honnce\n\n \n\n \n\nDie Stadt selbst ist unangenchm. dagegen rings umber aussprecbliche Sehentice der Satur May\nbewog den verstorbenen Grafen von M., einen Garten auf Wafer Hhigel ansulegen, dig nut det schansten,\nMannigfaltigkeit sich kreuzen und die fieblichsten Laler hilden. Der Gartva ost camlach, und nan Fill ele\nbei dem Rintritte, dal nicht ein wissensehaftlicher Gartner, sondern em Hihlondes Hers den Plan eset linet,\ndas seiner selbst hier genieBen wollte. Schon manche Iréine hab’ ich dein Abgeseheedemen in dem settalleien\nKabinetichen gewcint, das sein Lieblingsplitzchen war und auch memes ist Halt verde ih Her vi\n\nGarten sein; det Gartner ist mir cugetan. nur seit den paar Vagen, und er wind yuh nig ht ube! ater hetinndes\n\nif yy\n\nine\n\n \n\n   \n\n   \n\n   \n\n   \n\x0c"

# %%
# img = remove_noise(img)
# im = Image.fromarray(img)
# im

# %%
# ocr_core(img)
# Out:
# ' \n\n     \n\n \n\nwe ttt Meade\n\nfn Eaten ed ee eae\net unt = wee\nMen al +\n\n  \n\n \n\n   \n\n       \n\n       \n\nNet dee te Nae Date Ae om ee ane e rors\nSe te met ote fe Beet Ula a Hae a apart ce Evel a nd\nere nes tne ey o See\na ante amne Raila Net te gts be fe ape\nHae EO Pe elites ode meme he\nke ne ge ont ae Sa fr rere\nBe NO glee ae Terns A a gen * be be\n\n    \n\ncep we on see gt\n\n     \n\n       \n       \n\n \n\n     \n\n        \n\n \n\nSe ete geet rian eee Conny “ as\nDeen geen eteilh BA et ee sn oe . "\nsett See te ee ee sated Lae oe fae . tos “\nSees Ma Moe see ih ae ie a anit | ote . -\nBae atone eae Me Mca ae te .\n\nFg I eek ete aye nee eee a he . os\netd Wa Aaa aber a A Ge tet ag ERS 2 we\n\net ite Ok matt ae Ek aed Mente Bact bw gee\n\neget Met tal teen gee a\n\nFeelin ge unt Aen ote\nseen meen pe Ene on Samal\nRete cee RA tg ete sete: oe aM\n\n \n\n \n\na Ae tae seine ye get ote\nWapeng Mee nea eet copie Mee\n\n    \n\n      \n\nNeer gt se Renta vated He wth 6 a ante who .\n\nWee Ree Fert Un le Cte rea Meet Mee dete ea oe . .\nMh Yoo ett ge athe ee atten bette fee SN he na - “,\n\nRattle ge meat lime Mee wy ar A Tete eae ne see : *\n\n \n\ntae et Be gma Ue we\n\x0c'

# %%
i=5
mine = f"./data/test{i}.jpg"
tech = f"./data/testimage{i}.jpeg"
img=cv2.imread(mine)
im = Image.fromarray(img)
img = get_grayscale(img)
img = threshold(img)
img = remove_noise(img)
ocr_core(img)
# Out:
# ' \n\x0c'

# %%
cv2.imshow('sample image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
